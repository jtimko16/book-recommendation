# %% [markdown]
# ### Baseline model for predicting reccomended book

# %%
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append('../')

from functions.fun_model import recommend_books, not_recommended_books, prepare_data_assoc_rules, rank_books

# %% [markdown]
# ### Import dataset, split into train/val/test

# %%
df = pd.read_csv('model_data/model_data_wo_eXtern.csv')

print(df.shape)
df.head(5)
# Out:
# (1149780, 13)
#    User-ID   Age        City Region/State Country  Age_Missing        ISBN  \
# 0        2  18.0    stockton   california     usa            0  0195153448
# 1        7  -1.0  washington           dc     usa            1   034542252
# 2        8  -1.0     timmins      ontario  canada            1  0002005018
# 3        8  -1.0     timmins      ontario  canada            1  0060973129
# 4        8  -1.0     timmins      ontario  canada            1  0374157065
#
#    Book-Rating   Rating_Categ  \
# 0            0      Not rated
# 1            0      Not rated
# 2            5  Avarege (4-5)
# 3            0      Not rated
# 4            0      Not rated
#
#                                           Book-Title           Book-Author  \
# 0                                Classical Mythology    Mark P. O. Morford
# 1                                                NaN                   NaN
# 2                                       Clara Callan  Richard Bruce Wright
# 3                               Decision in Normandy          Carlo D'Este
# 4  Flu: The Story of the Great Influenza Pandemic...      Gina Bari Kolata
#
#    Year-Of-Publication                Publisher
# 0               2002.0  Oxford University Press
# 1                  NaN                      NaN
# 2               2001.0    HarperFlamingo Canada
# 3               1991.0          HarperPerennial
# 4               1999.0     Farrar Straus Giroux

# %% [markdown]
# ### Prepare data for association rules

# %%
df_subset = prepare_data_assoc_rules(df)
print(df_subset.shape)
df_subset.head(5)
# Out:
# (110362, 15)
#      User-ID   Age         City       Region/State  Country  Age_Missing  \
# 354      242  37.0      neuffen  badenwuerttemberg  germany            0
# 394      243  -1.0  arden hills          minnesota      usa            1
# 395      243  -1.0  arden hills          minnesota      usa            1
# 397      243  -1.0  arden hills          minnesota      usa            1
# 400      243  -1.0  arden hills          minnesota      usa            1
#
#            ISBN  Book-Rating      Rating_Categ                Book-Title  \
# 354  0971880107            0         Not rated               Wild Animus
# 394  0060915544           10  Excellent (8-10)            The Bean Trees
# 395  0060977493            7        Good (6-7)   The God of Small Things
# 397  0156006529            0         Not rated  Where or When  : A Novel
# 400  0316096199            0         Not rated          Lucky : A Memoir
#
#             Book-Author  Year-Of-Publication       Publisher  Recommend  \
# 354        Rich Shapero               2004.0         Too Far          0
# 394  Barbara Kingsolver               1989.0       Perennial          1
# 395       Arundhati Roy               1998.0       Perennial          1
# 397        Anita Shreve               1999.0   Harvest Books          0
# 400        Alice Sebold               2002.0  Back Bay Books          0
#
#      Not_Recommend
# 354              0
# 394              0
# 395              0
# 397              0
# 400              0

# %%
user_book_matrix = df_subset.pivot(index='User-ID', columns='ISBN', values='Recommend').fillna(0)

# %% [markdown]
# ### Simple reccomnendation system

# %%
# Example: User selects ISBN "12345"
#selected_book = "059035342X" # Harry Potter and the Sorcerer's Stone

selected_book = '0385504209' # The Da Vinci Code

### Look up book name for selected book
selected_book_name = df[df['ISBN'] == selected_book]['Book-Title'].values[0]
print(f"Selected Book: {selected_book_name}")

recommendations = recommend_books(selected_book, df_subset)
not_reccomendations = not_recommended_books(selected_book, df_subset)

### Join the two dataframes by the ISBN
merge_reccomendations = recommendations.merge(not_reccomendations, how='left', left_on='Book-Title', right_on='Book-Title').fillna(0)

## Calculate reccomneded %%!
merge_reccomendations['Recommendation_Percentage'] =100* merge_reccomendations['Count_recommend'] / (merge_reccomendations['Count_recommend'] + merge_reccomendations['Count_not_recommend'])
merge_reccomendations.head(5)
# Out:
# Selected Book: The Da Vinci Code
#                             Book-Title  Count_recommend  Count_not_recommend  \
# 0                  Angels &amp; Demons               34                  0.0
# 1            The Lovely Bones: A Novel               32                  0.0
# 2              The Secret Life of Bees               25                  1.0
# 3  The Red Tent (Bestselling Backlist)               19                  1.0
# 4                           Life of Pi               17                  0.0
#
#    Recommendation_Percentage
# 0                 100.000000
# 1                 100.000000
# 2                  96.153846
# 3                  95.000000
# 4                 100.000000

# %% [markdown]
# ### Objective function - find reccomended books

# %%
rank_books(merge_reccomendations, count_col="Count_recommend", percent_col="Recommendation_Percentage", top_n=100, w1=0.8, w2=0.2)
# Out:
#                                            Book-Title     Score  \
# 0                                 Angels &amp; Demons  1.000000
# 1                           The Lovely Bones: A Novel  0.951515
# 2                             The Secret Life of Bees  0.766434
# 3                 The Red Tent (Bestselling Backlist)  0.616364
# 4                                          Life of Pi  0.587879
# ..                                                ...       ...
# 86                                     Pay It Forward  0.345455
# 72  The Queen of the Damned (Vampire Chronicles (P...  0.345455
# 87  Confessions of a Shopaholic (Summer Display Op...  0.345455
# 93                                  The Last Precinct  0.345455
# 76                                 A Walk to Remember  0.345455
#
#     Count_recommend  Recommendation_Percentage
# 0                34                 100.000000
# 1                32                 100.000000
# 2                25                  96.153846
# 3                19                  95.000000
# 4                17                 100.000000
# ..              ...                        ...
# 86                7                 100.000000
# 72                7                 100.000000
# 87                7                 100.000000
# 93                7                 100.000000
# 76                7                 100.000000
#
# [100 rows x 4 columns]
